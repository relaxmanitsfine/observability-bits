# %%
# %sql
select *
  from system.access.column_lineage
 where source_table_full_name is not null

# %%
# %sql
select *
  from system.information_schema.tables

# %%
# %sql
select *
  from system.access.table_lineage
where target_table_full_name is not null
  and source_table_full_name is not null
  and target_type not in ('STREAMING_TABLE', 'VIEW')
  and entity_type is not null
  and entity_type not in ('PIPELINE')
  and event_date >= current_date() - interval 2 days

# %%
# %sql
select *
  from system.access.table_lineage
where target_table_full_name = 'geospatial_docs.neighbors.test_neighbors'
